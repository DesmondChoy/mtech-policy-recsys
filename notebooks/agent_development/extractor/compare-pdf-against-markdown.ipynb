# %%
import base64
import os
from google import genai
from google.genai import types
import json

# %%
api_key = ""
client = genai.Client(api_key=api_key)
model_id =  "gemini-2.5-pro-exp-03-25"

# %%
def open_and_read_json_file(json_name):
  with open(json_name, 'r') as f:
    json_string = f.read()
    json_data = convert_numeric_keys_to_string(json_string)
    json_string = json.dumps(json_data, indent=4, separators=(',', ': \n'))
    return json_string

def convert_numeric_keys_to_string(data):
    if isinstance(data, dict):
        return {str(k): convert_numeric_keys_to_string(v) for k, v in data.items()}
    elif isinstance(data, list):
        return [convert_numeric_keys_to_string(item) for item in data]
    else:
        return data

# %%
files = [
        client.files.upload(file="instructions_5.txt"),
        client.files.upload(file="Sompo-traveljoy.pdf")
    ]
policy_tier_name = "GO Japan!"

# compare pdf and json
response = client.models.generate_content(
    model=model_id,
    contents=[
         "do instruction in the .txt document, [POLICY TIER NAME]=" + policy_tier_name,
        files[0], # instructions
        open_and_read_json_file('sompo-gojapan.json'), # json extract
         files[1] # pdf
    ]
)
print(response.text)
# Out:
# ```json
# [
#   {
#     "result": "match",
#     "coverage_name": "Personal Accident"
#   },
#   {
#     "result": "no match",
#     "coverage_name": "Medical Expenses Incurred Upon Return to Singapore",
#     "json_detail": "Covers follow-up treatment within 15 days from return date.",
#     "pdf_detail": "Covers follow-up treatment within 31 days from return date (Page 3, Section 3 Description)."
#   },
#   {
#     "result": "match",
#     "coverage_name": "Guardian for Return of Dependent Children"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Loss or Damage to Baggage & Personal Effects"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Trip Cancellation or Postponement"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Baggage Delay"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Flight Deviation"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Kidnap Benefit"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Alternative Accommodation Arrangement"
#   },
#   {
#     "result": "match",
#     "coverage_name": "Golf Cover"
#   }
# ]
# ```
